# %%
import torch

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
MODEL_TYPE = "vit_t"

# %% [markdown]
# Load the YOLO model

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
model.to(DEVICE)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# Load the TinySAM

# %%
from tinysam import sam_model_registry, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint="./weights/tinysam.pth")
sam.to(DEVICE)
# Out:
# Sam(
#   (image_encoder): TinyViT(
#     (patch_embed): PatchEmbed(
#       (seq): Sequential(
#         (0): Conv2d_BN(
#           (c): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): GELU(approximate='none')
#         (2): Conv2d_BN(
#           (c): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layers): ModuleList(
#       (0): ConvLayer(
#         (blocks): ModuleList(
#           (0-1): 2 x MBConv(
#             (conv1): Conv2d_BN(
#               (c): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act1): GELU(approximate='none')
#             (conv2): Conv2d_BN(
#               (c): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act2): GELU(approximate='none')
#             (conv3): Conv2d_BN(
#               (c): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act3): GELU(approximate='none')
#             (drop_path): Identity()
#           )
#         )
#         (downsample): PatchMerging(
#           (act): GELU(approximate='none')
#           (conv1): Conv2d_BN(
#             (c): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d_BN(
#             (c): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d_BN(
#             (c): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (1): BasicLayer(
#         dim=128, input_resolution=(128, 128), depth=2
#         (blocks): ModuleList(
#           (0-1): 2 x TinyViTBlock(
#             dim=128, input_resolution=(128, 128), num_heads=4, window_size=7, mlp_ratio=4.0
#             (drop_path): Identity()
#             (attn): Attention(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               (qkv): Linear(in_features=128, out_features=384, bias=True)
#               (proj): Linear(in_features=128, out_features=128, bias=True)
#             )
#             (mlp): Mlp(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=128, out_features=512, bias=True)
#               (fc2): Linear(in_features=512, out_features=128, bias=True)
#               (act): GELU(approximate='none')
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#             (local_conv): Conv2d_BN(
#               (c): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (downsample): PatchMerging(
#           (act): GELU(approximate='none')
#           (conv1): Conv2d_BN(
#             (c): Conv2d(128, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d_BN(
#             (c): Conv2d(160, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=160, bias=False)
#             (bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d_BN(
#             (c): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (2): BasicLayer(
#         dim=160, input_resolution=(64, 64), depth=6
#         (blocks): ModuleList(
#           (0-5): 6 x TinyViTBlock(
#             dim=160, input_resolution=(64, 64), num_heads=5, window_size=14, mlp_ratio=4.0
#             (drop_path): Identity()
#             (attn): Attention(
#               (norm): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#               (qkv): Linear(in_features=160, out_features=480, bias=True)
#               (proj): Linear(in_features=160, out_features=160, bias=True)
#             )
#             (mlp): Mlp(
#               (norm): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=160, out_features=640, bias=True)
#               (fc2): Linear(in_features=640, out_features=160, bias=True)
#               (act): GELU(approximate='none')
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#             (local_conv): Conv2d_BN(
#               (c): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#               (bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (downsample): PatchMerging(
#           (act): GELU(approximate='none')
#           (conv1): Conv2d_BN(
#             (c): Conv2d(160, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d_BN(
#             (c): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320, bias=False)
#             (bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d_BN(
#             (c): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (3): BasicLayer(
#         dim=320, input_resolution=(64, 64), depth=2
#         (blocks): ModuleList(
#           (0-1): 2 x TinyViTBlock(
#             dim=320, input_resolution=(64, 64), num_heads=10, window_size=7, mlp_ratio=4.0
#             (drop_path): Identity()
#             (attn): Attention(
#               (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               (qkv): Linear(in_features=320, out_features=960, bias=True)
#               (proj): Linear(in_features=320, out_features=320, bias=True)
#             )
#             (mlp): Mlp(
#               (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=320, out_features=1280, bias=True)
#               (fc2): Linear(in_features=1280, out_features=320, bias=True)
#               (act): GELU(approximate='none')
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#             (local_conv): Conv2d_BN(
#               (c): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320, bias=False)
#               (bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#     )
#     (norm_head): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     (head): Linear(in_features=320, out_features=1000, bias=True)
#     (neck): Sequential(
#       (0): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): LayerNorm2d()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (3): LayerNorm2d()
#     )
#   )
#   (prompt_encoder): PromptEncoder(
#     (pe_layer): PositionEmbeddingRandom()
#     (point_embeddings): ModuleList(
#       (0-3): 4 x Embedding(1, 256)
#     )
#     (not_a_point_embed): Embedding(1, 256)
#     (mask_downscaling): Sequential(
#       (0): Conv2d(1, 4, kernel_size=(2, 2), stride=(2, 2))
#       (1): LayerNorm2d()
#       (2): GELU(approximate='none')
#       (3): Conv2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#       (4): LayerNorm2d()
#       (5): GELU(approximate='none')
#       (6): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (no_mask_embed): Embedding(1, 256)
#   )
#   (mask_decoder): MaskDecoder(
#     (transformer): TwoWayTransformer(
#       (layers): ModuleList(
#         (0-1): 2 x TwoWayAttentionBlock(
#           (self_attn): Attention(
#             (q_proj): Linear(in_features=256, out_features=256, bias=True)
#             (k_proj): Linear(in_features=256, out_features=256, bias=True)
#             (v_proj): Linear(in_features=256, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_token_to_image): Attention(
#             (q_proj): Linear(in_features=256, out_features=128, bias=True)
#             (k_proj): Linear(in_features=256, out_features=128, bias=True)
#             (v_proj): Linear(in_features=256, out_features=128, bias=True)
#             (out_proj): Linear(in_features=128, out_features=256, bias=True)
#           )
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (lin1): Linear(in_features=256, out_features=2048, bias=True)
#             (lin2): Linear(in_features=2048, out_features=256, bias=True)
#             (act): ReLU()
#           )
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm4): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_image_to_token): Attention(
#             (q_proj): Linear(in_features=256, out_features=128, bias=True)
#             (k_proj): Linear(in_features=256, out_features=128, bias=True)
#             (v_proj): Linear(in_features=256, out_features=128, bias=True)
#             (out_proj): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#       (final_attn_token_to_image): Attention(
#         (q_proj): Linear(in_features=256, out_features=128, bias=True)
#         (k_proj): Linear(in_features=256, out_features=128, bias=True)
#         (v_proj): Linear(in_features=256, out_features=128, bias=True)
#         (out_proj): Linear(in_features=128, out_features=256, bias=True)
#       )
#       (norm_final_attn): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (iou_token): Embedding(1, 256)
#     (mask_tokens): Embedding(4, 256)
#     (output_upscaling): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#       (1): LayerNorm2d()
#       (2): GELU(approximate='none')
#       (3): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#       (4): GELU(approximate='none')
#     )
#     (output_hypernetworks_mlps): ModuleList(
#       (0-3): 4 x MLP(
#         (layers): ModuleList(
#           (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#           (2): Linear(in_features=256, out_features=32, bias=True)
#         )
#       )
#     )
#     (iou_prediction_head): MLP(
#       (layers): ModuleList(
#         (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         (2): Linear(in_features=256, out_features=4, bias=True)
#       )
#     )
#   )
# )

# %%
sam_predictor = SamPredictor(sam)

# %% [markdown]
# Video inference

# %%
import cv2
import numpy as np

# %%
video_path = "fight_2.mp4"
cap = cv2.VideoCapture(video_path)

output_path = "result_2.avi"
fourcc = cv2.VideoWriter_fourcc(*'XVID')
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    composite_mask = np.zeros_like(frame, dtype=np.uint8)

    objects = model(frame, classes=[0], conf=0.6)

    for obj in objects:
        boxes = obj.boxes
        cls = boxes.cls

        classes = ['person']

        for i in range(len(boxes)):
            class_name = classes[int(cls[i])]
            print(class_name)

            #Extort the box coordination
            xyxy = boxes.xyxy[i]
            x1, y1, x2, y2 = xyxy.cpu().numpy()
            
            #Plot the rectangle on to the frame
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

            #Add text to the rectangle
            text = class_name
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.5
            thickness = 2
            text_size, _ = cv2.getTextSize(text, font, font_scale, thickness)
            text_x = int(x1 + 5)
            text_y = int(y1 + text_size[1] + 5)
            cv2.putText(frame, text, (text_x, text_y), font, font_scale, (0, 0, 255), thickness)

            """
            Use the box and inference it to the SAM model
            """

            sam_predictor.set_image(frame)
            input_box = np.array(xyxy.cpu().numpy())

            masks, _, _ = sam_predictor.predict(
                point_coords=None,
                point_labels=None,
                box=input_box[None, :],
            )

            mask = masks[0]
            colored_mask = np.zeros_like(frame)
            colored_mask[mask > 0] = [0, 255, 0]
            composite_mask = cv2.add(composite_mask, colored_mask)
    
    alpha = 0.5
    frame = cv2.addWeighted(frame, 1 - alpha, composite_mask, alpha, 0)

    out.write(frame)
    
    cv2.imshow("Frame with person segmentation", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 40.3ms
# Speed: 4.9ms preprocess, 40.3ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 17.8ms
# Speed: 3.0ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 37.7ms
# Speed: 3.8ms preprocess, 37.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.2ms
# Speed: 2.9ms preprocess, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 18.8ms
# Speed: 2.3ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 35.6ms
# Speed: 2.3ms preprocess, 35.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.2ms
# Speed: 2.2ms preprocess, 10.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 26.0ms
# Speed: 2.4ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 19.8ms
# Speed: 2.5ms preprocess, 19.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 30.6ms
# Speed: 2.2ms preprocess, 30.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 21.7ms
# Speed: 2.0ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 28.6ms
# Speed: 2.6ms preprocess, 28.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 1 person, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
#
# 0: 384x640 2 persons, 28.6ms
# Speed: 2.3ms preprocess, 28.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 12.6ms
# Speed: 2.6ms preprocess, 12.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 26.1ms
# Speed: 2.6ms preprocess, 26.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 15.5ms
# Speed: 1.8ms preprocess, 15.5ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 8.4ms
# Speed: 2.3ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 12.3ms
# Speed: 2.2ms preprocess, 12.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 18.9ms
# Speed: 3.3ms preprocess, 18.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 30.6ms
# Speed: 2.6ms preprocess, 30.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 28.0ms
# Speed: 2.7ms preprocess, 28.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 11.7ms
# Speed: 2.3ms preprocess, 11.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 28.3ms
# Speed: 2.6ms preprocess, 28.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 31.5ms
# Speed: 2.4ms preprocess, 31.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 30.3ms
# Speed: 2.0ms preprocess, 30.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 34.3ms
# Speed: 2.3ms preprocess, 34.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 3 persons, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 12.4ms
# Speed: 2.6ms preprocess, 12.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# 0: 384x640 2 persons, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
#
# ...
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 25.0ms
# Speed: 3.5ms preprocess, 25.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 25.8ms
# Speed: 2.6ms preprocess, 25.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 32.7ms
# Speed: 2.6ms preprocess, 32.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 30.5ms
# Speed: 2.4ms preprocess, 30.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.3ms
# Speed: 4.2ms preprocess, 9.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 3 persons, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 3 persons, 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
#
# 0: 384x640 4 persons, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 4 persons, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 30.7ms
# Speed: 2.3ms preprocess, 30.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.6ms
# Speed: 3.3ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 37.7ms
# Speed: 2.2ms preprocess, 37.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 37.7ms
# Speed: 2.2ms preprocess, 37.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 29.3ms
# Speed: 3.2ms preprocess, 29.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 5 persons, 11.6ms
# Speed: 2.2ms preprocess, 11.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 14.1ms
# Speed: 4.7ms preprocess, 14.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 8.4ms
# Speed: 4.1ms preprocess, 8.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
#
# 0: 384x640 6 persons, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# person
# person
# person
# person
# person
# person
